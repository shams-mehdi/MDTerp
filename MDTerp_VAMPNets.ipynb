# %%
## Download relevant data+models for testing MDTerp

import urllib.request
import zipfile
import os

url = "https://figshare.com/ndownloader/articles/30351334/versions/7"
filename = "MDTerp_files.zip"

urllib.request.urlretrieve(url, filename)
print(f"Downloaded {filename}")

zip_path = "MDTerp_files.zip"
extract_dir = "./"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"Files extracted to: {extract_dir}")
# Out:
# Downloaded MDTerp_files.zip
# Files extracted to: ./

# %%
# MDTerp step 1: Load alanine dipeptide in vacuum simulation trajectory (φ, ψ, θ, ω) and convert into sine/cosines since the VAMPNets model was trained using these 8 features

import numpy as np
import os

result_dir = './results/'
os.makedirs(result_dir, exist_ok = True)

aladip_all = np.load('MDTerp_files/data_model/VAMPnets_alanine_dipeptide_trajectory.npy')
aladip_all_sin_cos = np.zeros((aladip_all.shape[0], 8))
for i in range(4):
  aladip_all_sin_cos[:, 2*i] = np.sin(aladip_all[:,i])
  aladip_all_sin_cos[:, 2*i+1] = np.cos(aladip_all[:,i])

# %%
# MDTerp step 2: Create feature dictionary

sin_cos_dict = {}
sin_cos_dict["φ"] = [0, 1]
sin_cos_dict["ψ"] = [2, 3]
sin_cos_dict["θ"] = [4, 5]
sin_cos_dict["ω"] = [6, 7]

# %%
# MDTerp step 3: Import MDTerp.base and implement MDTerp using base.run(). Two required arguments are the dataset and the location of a Python function that loads a black-box model. Go to https://github.com/shams-mehdi/MDTerp/tree/main/examples to check how this Python file should be like.

import MDTerp.base as base

model_function_loc = 'MDTerp_files/scripts/MDTerp_script_VAMPnets.txt'
base.run(aladip_all_sin_cos, model_function_loc, save_dir = result_dir, sin_cos_dict = sin_cos_dict , point_max = 100, prob_threshold = 0.4, num_samples = 10000)
# Out:
# 10-17-25 17:32:51 initialization  INFO     ----------------------------------------------------------------------------------------------------
# 10-17-25 17:32:51 initialization  INFO     Starting MDTerp...
# 10-17-25 17:32:51 initialization  INFO     ----------------------------------------------------------------------------------------------------
# 10-17-25 17:32:51 initialization  INFO     MDTerp result location >>> ./results/
# 10-17-25 17:32:51 initialization  INFO     Defined numeric features >>> 0
# 10-17-25 17:32:51 initialization  INFO     Defined angle features >>> 0
# 10-17-25 17:32:51 initialization  INFO     Defined sin_cos features >>> 4
# 10-17-25 17:32:51 initialization  INFO     Number of samples in blackbox model training data >>> 2000000
# 10-17-25 17:32:51 initialization  INFO     Number of columns in blackbox model training data >>> 8
# 10-17-25 17:32:51 initialization  INFO     ----------------------------------------------------------------------------------------------------
# 10-17-25 17:32:51 initialization  INFO     Loading blackbox model from file >>> MDTerp_files/scripts/MDTerp_script_VAMPnets.txt
# C:\Users\shams\anaconda3\envs\umd\Lib\site-packages\deeptime\base.py:116: UserWarning: Trying to unpickle estimator VAMPNetModel from version 0.4.4 when using version 0.4.5. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# 10-17-25 17:32:52 initialization  INFO     Model loaded!
# 10-17-25 17:32:59 initialization  INFO     Number of state transitions detected >>> 2
# 10-17-25 17:32:59 initialization  INFO     Probability threshold, maximum number of points per transition >>> 0.4, 100
# 10-17-25 17:32:59 initialization  INFO     ----------------------------------------------------------------------------------------------------
# 10-17-25 17:32:59 initialization  INFO     Starting transition >>> 0_1
# 10-17-25 17:33:00 initialization  INFO     Completed generating 1/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:01 initialization  INFO     Completed generating 2/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:02 initialization  INFO     Completed generating 3/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:02 initialization  INFO     Completed generating 4/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:03 initialization  INFO     Completed generating 5/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:04 initialization  INFO     Completed generating 6/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:05 initialization  INFO     Completed generating 7/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:05 initialization  INFO     Completed generating 8/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:06 initialization  INFO     Completed generating 9/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:07 initialization  INFO     Completed generating 10/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:08 initialization  INFO     Completed generating 11/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:08 initialization  INFO     Completed generating 12/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:09 initialization  INFO     Completed generating 13/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:10 initialization  INFO     Completed generating 14/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:11 initialization  INFO     Completed generating 15/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:11 initialization  INFO     Completed generating 16/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:12 initialization  INFO     Completed generating 17/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:13 initialization  INFO     Completed generating 18/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:14 initialization  INFO     Completed generating 19/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:14 initialization  INFO     Completed generating 20/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:15 initialization  INFO     Completed generating 21/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:16 initialization  INFO     Completed generating 22/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:17 initialization  INFO     Completed generating 23/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:18 initialization  INFO     Completed generating 24/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:18 initialization  INFO     Completed generating 25/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:19 initialization  INFO     Completed generating 26/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:20 initialization  INFO     Completed generating 27/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:21 initialization  INFO     Completed generating 28/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:21 initialization  INFO     Completed generating 29/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:22 initialization  INFO     Completed generating 30/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:23 initialization  INFO     Completed generating 31/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:24 initialization  INFO     Completed generating 32/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:25 initialization  INFO     Completed generating 33/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:25 initialization  INFO     Completed generating 34/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:26 initialization  INFO     Completed generating 35/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:27 initialization  INFO     Completed generating 36/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:28 initialization  INFO     Completed generating 37/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:28 initialization  INFO     Completed generating 38/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:29 initialization  INFO     Completed generating 39/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:30 initialization  INFO     Completed generating 40/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:31 initialization  INFO     Completed generating 41/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:32 initialization  INFO     Completed generating 42/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:32 initialization  INFO     Completed generating 43/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:33 initialization  INFO     Completed generating 44/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:34 initialization  INFO     Completed generating 45/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:35 initialization  INFO     Completed generating 46/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:35 initialization  INFO     Completed generating 47/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:36 initialization  INFO     Completed generating 48/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:37 initialization  INFO     Completed generating 49/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:38 initialization  INFO     Completed generating 50/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:39 initialization  INFO     Completed generating 51/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:39 initialization  INFO     Completed generating 52/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:40 initialization  INFO     Completed generating 53/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:41 initialization  INFO     Completed generating 54/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:42 initialization  INFO     Completed generating 55/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:42 initialization  INFO     Completed generating 56/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:43 initialization  INFO     Completed generating 57/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:44 initialization  INFO     Completed generating 58/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:45 initialization  INFO     Completed generating 59/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:45 initialization  INFO     Completed generating 60/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:46 initialization  INFO     Completed generating 61/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:47 initialization  INFO     Completed generating 62/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:48 initialization  INFO     Completed generating 63/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:49 initialization  INFO     Completed generating 64/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:49 initialization  INFO     Completed generating 65/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:50 initialization  INFO     Completed generating 66/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:51 initialization  INFO     Completed generating 67/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:52 initialization  INFO     Completed generating 68/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:52 initialization  INFO     Completed generating 69/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:53 initialization  INFO     Completed generating 70/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:54 initialization  INFO     Completed generating 71/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:55 initialization  INFO     Completed generating 72/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:56 initialization  INFO     Completed generating 73/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:56 initialization  INFO     Completed generating 74/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:57 initialization  INFO     Completed generating 75/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:58 initialization  INFO     Completed generating 76/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:59 initialization  INFO     Completed generating 77/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:33:59 initialization  INFO     Completed generating 78/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:00 initialization  INFO     Completed generating 79/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:01 initialization  INFO     Completed generating 80/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:02 initialization  INFO     Completed generating 81/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:03 initialization  INFO     Completed generating 82/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:03 initialization  INFO     Completed generating 83/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:04 initialization  INFO     Completed generating 84/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:05 initialization  INFO     Completed generating 85/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:06 initialization  INFO     Completed generating 86/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:06 initialization  INFO     Completed generating 87/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:07 initialization  INFO     Completed generating 88/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:08 initialization  INFO     Completed generating 89/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:09 initialization  INFO     Completed generating 90/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:10 initialization  INFO     Completed generating 91/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:10 initialization  INFO     Completed generating 92/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:11 initialization  INFO     Completed generating 93/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:12 initialization  INFO     Completed generating 94/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:13 initialization  INFO     Completed generating 95/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:13 initialization  INFO     Completed generating 96/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:14 initialization  INFO     Completed generating 97/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:15 initialization  INFO     Completed generating 98/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:16 initialization  INFO     Completed generating 99/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:16 initialization  INFO     Completed generating 100/100 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:16 initialization  INFO     ____________________________________________________________________________________________________
# 10-17-25 17:34:16 initialization  INFO     Starting transition >>> 1_2
# 10-17-25 17:34:17 initialization  INFO     Completed generating 1/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:18 initialization  INFO     Completed generating 2/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:19 initialization  INFO     Completed generating 3/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:19 initialization  INFO     Completed generating 4/44 results! First round features kept >>> 8, Final round features kept >>> 1
# 10-17-25 17:34:20 initialization  INFO     Completed generating 5/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:21 initialization  INFO     Completed generating 6/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:22 initialization  INFO     Completed generating 7/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:23 initialization  INFO     Completed generating 8/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:23 initialization  INFO     Completed generating 9/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:24 initialization  INFO     Completed generating 10/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:25 initialization  INFO     Completed generating 11/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:26 initialization  INFO     Completed generating 12/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:26 initialization  INFO     Completed generating 13/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:27 initialization  INFO     Completed generating 14/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:28 initialization  INFO     Completed generating 15/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:29 initialization  INFO     Completed generating 16/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:30 initialization  INFO     Completed generating 17/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:31 initialization  INFO     Completed generating 18/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:32 initialization  INFO     Completed generating 19/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:33 initialization  INFO     Completed generating 20/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:33 initialization  INFO     Completed generating 21/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:34 initialization  INFO     Completed generating 22/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:35 initialization  INFO     Completed generating 23/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:36 initialization  INFO     Completed generating 24/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:36 initialization  INFO     Completed generating 25/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:37 initialization  INFO     Completed generating 26/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:38 initialization  INFO     Completed generating 27/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:39 initialization  INFO     Completed generating 28/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:40 initialization  INFO     Completed generating 29/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:40 initialization  INFO     Completed generating 30/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:41 initialization  INFO     Completed generating 31/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:42 initialization  INFO     Completed generating 32/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:43 initialization  INFO     Completed generating 33/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:43 initialization  INFO     Completed generating 34/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:44 initialization  INFO     Completed generating 35/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:45 initialization  INFO     Completed generating 36/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:46 initialization  INFO     Completed generating 37/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:46 initialization  INFO     Completed generating 38/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:47 initialization  INFO     Completed generating 39/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:48 initialization  INFO     Completed generating 40/44 results! First round features kept >>> 8, Final round features kept >>> 3
# 10-17-25 17:34:49 initialization  INFO     Completed generating 41/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:49 initialization  INFO     Completed generating 42/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:50 initialization  INFO     Completed generating 43/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:51 initialization  INFO     Completed generating 44/44 results! First round features kept >>> 8, Final round features kept >>> 2
# 10-17-25 17:34:51 initialization  INFO     ____________________________________________________________________________________________________
# 10-17-25 17:34:51 initialization  INFO     Feature names saved at >>> ./results/MDTerp_feature_names.npy
# 10-17-25 17:34:51 initialization  INFO     All results saved at >>> ./results/MDTerp_results_all.pkl
# 10-17-25 17:34:51 initialization  INFO     Completed!!!

# %%
# MDTerp step 3: Summarize feature importance for each of the transition states.
import matplotlib.pyplot as plt
from MDTerp.utils import transition_summary

feature_names_loc = result_dir + 'MDTerp_feature_names.npy'
feature_names = np.load(feature_names_loc)
all_result_loc = result_dir + 'MDTerp_results_all.pkl'

# summary is a dictionary with individual keys for each class transition in the dataset. Each key has the mean and standard deviation of feature importance for all explanations generated for that transition
summary = transition_summary(all_result_loc, importance_coverage = 1.00)

# Loop over all the transitions
for ii in summary:
    ordered_nonzero_indices = np.argsort(summary[ii][0])[::-1][:np.nonzero(summary[ii][0])[0].shape[0]]
    
    ordered_mean = summary[ii][0][ordered_nonzero_indices]
    ordered_std = summary[ii][1][ordered_nonzero_indices]
    
    fig, ax = plt.subplots(figsize = (8,8))
    ax.barh(np.arange(ordered_mean.shape[0]), ordered_mean, xerr = ordered_std, capsize = 10)
    ax.set_title('Importance coverage: ' + str(int(100*np.sum(ordered_mean))) + '%' + '\n Transition state IDs-> ' + ii, fontsize = 24)
    ax.tick_params(axis='both', which='major', labelsize=24)
    ax.set_yticks(np.arange(ordered_nonzero_indices.shape[0]))
    ax.set_yticklabels(np.array(feature_names)[ordered_nonzero_indices])
    fig.tight_layout()

# %%
# For all the investigated points, fetch n_th dominant features (n = 0 is most dominant).
from MDTerp.utils import dominant_feature
dominant_feature(all_result_loc, n = 0)
# Out:
# {np.int64(1951934): np.int64(1),
#  np.int64(1134845): np.int64(1),
#  np.int64(802240): np.int64(1),
#  np.int64(1817481): np.int64(1),
#  np.int64(1582963): np.int64(1),
#  np.int64(730154): np.int64(1),
#  np.int64(1992227): np.int64(1),
#  np.int64(1621213): np.int64(1),
#  np.int64(1314405): np.int64(1),
#  np.int64(898319): np.int64(1),
#  np.int64(1986106): np.int64(1),
#  np.int64(661361): np.int64(1),
#  np.int64(329076): np.int64(1),
#  np.int64(1649437): np.int64(1),
#  np.int64(895463): np.int64(1),
#  np.int64(1558881): np.int64(1),
#  np.int64(1831674): np.int64(1),
#  np.int64(189338): np.int64(1),
#  np.int64(1317761): np.int64(1),
#  np.int64(1577675): np.int64(1),
#  np.int64(14072): np.int64(1),
#  np.int64(1138057): np.int64(1),
#  np.int64(293903): np.int64(1),
#  np.int64(693718): np.int64(1),
#  np.int64(898372): np.int64(1),
#  np.int64(571703): np.int64(1),
#  np.int64(205347): np.int64(1),
#  np.int64(1743773): np.int64(1),
#  np.int64(1355251): np.int64(1),
#  np.int64(1374655): np.int64(1),
#  np.int64(1440220): np.int64(1),
#  np.int64(839025): np.int64(1),
#  np.int64(862029): np.int64(1),
#  np.int64(1844686): np.int64(1),
#  np.int64(811205): np.int64(1),
#  np.int64(1576322): np.int64(1),
#  np.int64(63277): np.int64(1),
#  np.int64(1923237): np.int64(1),
#  np.int64(1289876): np.int64(1),
#  np.int64(1439290): np.int64(1),
#  np.int64(259873): np.int64(1),
#  np.int64(902855): np.int64(1),
#  np.int64(613783): np.int64(1),
#  np.int64(287398): np.int64(1),
#  np.int64(1348314): np.int64(1),
#  np.int64(368271): np.int64(1),
#  np.int64(486358): np.int64(1),
#  np.int64(766228): np.int64(1),
#  np.int64(1629799): np.int64(1),
#  np.int64(256649): np.int64(1),
#  np.int64(1933034): np.int64(1),
#  np.int64(1716114): np.int64(1),
#  np.int64(1309244): np.int64(1),
#  np.int64(1884182): np.int64(1),
#  np.int64(901477): np.int64(1),
#  np.int64(793302): np.int64(1),
#  np.int64(283066): np.int64(1),
#  np.int64(1937752): np.int64(1),
#  np.int64(341466): np.int64(1),
#  np.int64(1745636): np.int64(1),
#  np.int64(1074458): np.int64(1),
#  np.int64(1428062): np.int64(1),
#  np.int64(1101826): np.int64(1),
#  np.int64(937508): np.int64(1),
#  np.int64(508358): np.int64(1),
#  np.int64(666765): np.int64(1),
#  np.int64(1957393): np.int64(1),
#  np.int64(217764): np.int64(1),
#  np.int64(1015471): np.int64(1),
#  np.int64(382834): np.int64(1),
#  np.int64(1424482): np.int64(1),
#  np.int64(1309346): np.int64(1),
#  np.int64(1416773): np.int64(1),
#  np.int64(833629): np.int64(1),
#  np.int64(521419): np.int64(1),
#  np.int64(463204): np.int64(1),
#  np.int64(1529911): np.int64(1),
#  np.int64(218709): np.int64(1),
#  np.int64(1915819): np.int64(1),
#  np.int64(1119221): np.int64(1),
#  np.int64(928326): np.int64(1),
#  np.int64(275322): np.int64(1),
#  np.int64(488241): np.int64(1),
#  np.int64(979693): np.int64(1),
#  np.int64(451874): np.int64(1),
#  np.int64(1825644): np.int64(1),
#  np.int64(673250): np.int64(1),
#  np.int64(540121): np.int64(1),
#  np.int64(733280): np.int64(1),
#  np.int64(1372325): np.int64(1),
#  np.int64(1648836): np.int64(1),
#  np.int64(532931): np.int64(1),
#  np.int64(1306916): np.int64(1),
#  np.int64(1296745): np.int64(1),
#  np.int64(760609): np.int64(1),
#  np.int64(110898): np.int64(1),
#  np.int64(213173): np.int64(1),
#  np.int64(414034): np.int64(1),
#  np.int64(922108): np.int64(1),
#  np.int64(927616): np.int64(1),
#  np.int64(1603951): np.int64(0),
#  np.int64(1898484): np.int64(0),
#  np.int64(879430): np.int64(0),
#  np.int64(606001): np.int64(0),
#  np.int64(1899728): np.int64(0),
#  np.int64(204668): np.int64(0),
#  np.int64(855572): np.int64(0),
#  np.int64(1950289): np.int64(0),
#  np.int64(375620): np.int64(0),
#  np.int64(619259): np.int64(0),
#  np.int64(742684): np.int64(0),
#  np.int64(998695): np.int64(0),
#  np.int64(371987): np.int64(0),
#  np.int64(1602189): np.int64(0),
#  np.int64(204667): np.int64(0),
#  np.int64(1145988): np.int64(0),
#  np.int64(92143): np.int64(0),
#  np.int64(1898483): np.int64(0),
#  np.int64(114940): np.int64(0),
#  np.int64(566690): np.int64(0),
#  np.int64(1602191): np.int64(0),
#  np.int64(680972): np.int64(0),
#  np.int64(975795): np.int64(0),
#  np.int64(1934800): np.int64(0),
#  np.int64(1935506): np.int64(0),
#  np.int64(855571): np.int64(0),
#  np.int64(879435): np.int64(0),
#  np.int64(216891): np.int64(0),
#  np.int64(1145989): np.int64(0),
#  np.int64(680975): np.int64(0),
#  np.int64(216890): np.int64(0),
#  np.int64(1284644): np.int64(0),
#  np.int64(1100942): np.int64(0),
#  np.int64(566688): np.int64(0),
#  np.int64(879433): np.int64(0),
#  np.int64(1258873): np.int64(0),
#  np.int64(1431463): np.int64(0),
#  np.int64(1914419): np.int64(0),
#  np.int64(879434): np.int64(0),
#  np.int64(975796): np.int64(0),
#  np.int64(1142886): np.int64(0),
#  np.int64(879432): np.int64(0),
#  np.int64(1143111): np.int64(0),
#  np.int64(808657): np.int64(0)}
