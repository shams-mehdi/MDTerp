# %%
## Download relevant data+models for testing MDTerp

import urllib.request
import zipfile
import os

url = "https://figshare.com/ndownloader/articles/30351334/versions/9"
filename = "MDTerp_files.zip"

urllib.request.urlretrieve(url, filename)
print(f"Downloaded {filename}")

zip_path = "MDTerp_files.zip"
extract_dir = "./"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"Files extracted to: {extract_dir}")
# Out:
# Downloaded MDTerp_files.zip
# Files extracted to: ./

# %%
# MDTerp step 1: Load alanine dipeptide in vacuum simulation trajectory (φ, ψ, θ, ω) and convert into sine/cosines since the VAMPNets model was trained using these 8 features

import numpy as np
import os

result_dir = './results_vamp/'
os.makedirs(result_dir, exist_ok = True)

aladip_all = np.load('MDTerp_files/data_model/VAMPnets_alanine_dipeptide_trajectory.npy')
aladip_all_sin_cos = np.zeros((aladip_all.shape[0], 8))
for i in range(4):
  aladip_all_sin_cos[:, 2*i] = np.sin(aladip_all[:,i])
  aladip_all_sin_cos[:, 2*i+1] = np.cos(aladip_all[:,i])

# %%
# MDTerp step 2: Create feature dictionary

sin_cos_dict = {}
sin_cos_dict["φ"] = [0, 1]
sin_cos_dict["ψ"] = [2, 3]
sin_cos_dict["θ"] = [4, 5]
sin_cos_dict["ω"] = [6, 7]

# %%
# MDTerp step 3: Import MDTerp.base and implement MDTerp using base.run(). Two required arguments are the dataset and the location of a Python function that loads a black-box model. Go to https://github.com/shams-mehdi/MDTerp/tree/main/examples to check how this Python file should be like.

import MDTerp.base as base

model_function_loc = 'MDTerp_files/scripts/MDTerp_script_VAMPnets.txt'
base.run(aladip_all_sin_cos, model_function_loc, save_dir = result_dir, sin_cos_dict = sin_cos_dict , point_max = 100, prob_threshold_min = 0.4, num_samples = 10000, n_workers = 8, keep_checkpoints = True)
# Out:
# 03-16-26 03:14:00 MDTerp          INFO     ----------------------------------------------------------------------------------------------------
# 03-16-26 03:14:00 MDTerp          INFO     Starting MDTerp...
# 03-16-26 03:14:00 MDTerp          INFO     ----------------------------------------------------------------------------------------------------
# 03-16-26 03:14:00 MDTerp          INFO     MDTerp result location >>> ./results_vamp/
# 03-16-26 03:14:00 MDTerp          INFO     Defined numeric features >>> 0
# 03-16-26 03:14:00 MDTerp          INFO     Defined angle features >>> 0
# 03-16-26 03:14:00 MDTerp          INFO     Defined sin_cos features >>> 4
# 03-16-26 03:14:00 MDTerp          INFO     Number of samples in blackbox model training data >>> 2000000
# 03-16-26 03:14:00 MDTerp          INFO     Number of columns in blackbox model training data >>> 8
# 03-16-26 03:14:00 MDTerp          INFO     ----------------------------------------------------------------------------------------------------
# 03-16-26 03:14:00 MDTerp          INFO     Loading black-box model from file >>> MDTerp_files/scripts/MDTerp_script_VAMPnets.txt
# 03-16-26 03:14:00 MDTerp          INFO     Model loaded!
# 03-16-26 03:14:06 MDTerp          INFO     Number of state transitions detected >>> 2
# 03-16-26 03:14:06 MDTerp          INFO       Transition 0_1: 100 points, effective threshold = 0.450282
# 03-16-26 03:14:06 MDTerp          INFO       Transition 1_2: 44 points, effective threshold = 0.400944
# 03-16-26 03:14:06 MDTerp          INFO     ----------------------------------------------------------------------------------------------------
# 03-16-26 03:14:06 MDTerp          INFO     Analyzing 144 points using 8 workers...
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 0: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 1: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 2: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 3: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 4: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 5: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 6: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 7: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 8: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 9: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 10: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 11: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 12: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 13: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 14: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 15: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 16: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 17: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 18: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 19: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 20: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 21: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 22: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 23: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 24: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 25: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 26: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 27: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 28: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 29: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 30: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 31: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 32: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 33: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 34: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 35: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 36: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 37: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 38: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 39: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 40: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 41: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 42: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 43: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 44: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 45: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 46: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 47: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 48: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 49: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 50: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 51: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 52: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 53: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 54: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 55: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 56: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 57: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 58: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 59: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 60: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 61: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 62: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 63: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 64: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 65: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 66: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 67: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 68: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 69: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 70: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 71: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 72: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 73: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 74: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 75: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 76: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 77: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 78: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 79: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 80: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 81: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 82: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 83: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 84: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 85: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 86: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 87: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 88: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 89: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 90: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 91: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 92: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 93: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 94: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 95: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 96: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 97: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 98: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 0_1 point 99: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 0: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 1: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 2: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 3: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 4: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 5: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 6: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 7: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 8: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 9: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 10: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 11: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 12: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 13: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 14: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 15: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 16: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 17: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 18: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 19: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 20: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 21: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 22: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 23: round 1 features = 8, final features = 1
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 24: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 25: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 26: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 27: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 28: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 29: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 30: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 31: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 32: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 33: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 34: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 35: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 36: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 37: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 38: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 39: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 40: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 41: round 1 features = 8, final features = 3
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 42: round 1 features = 8, final features = 2
# 03-16-26 03:14:54 MDTerp          INFO     Completed 1_2 point 43: round 1 features = 8, final features = 3
# 03-16-26 03:14:55 MDTerp          INFO     Feature names saved at >>> ./results_vamp/MDTerp_feature_names.npy
# 03-16-26 03:14:55 MDTerp          INFO     All results saved at >>> ./results_vamp/MDTerp_results_all.pkl
# 03-16-26 03:14:55 MDTerp          INFO     Completed!

# %%
# MDTerp step 3: Summarize feature importance for each of the transition states.
import MDTerp

feature_names_loc = result_dir + 'MDTerp_feature_names.npy'
feature_names = np.load(feature_names_loc)
all_result_loc = result_dir + 'MDTerp_results_all.pkl'

# summary is a dictionary with individual keys for each class transition in the dataset. Each key has the mean and standard deviation of feature importance for all explanations generated for that transition
summary = MDTerp.transition_summary(all_result_loc, importance_coverage = 1.00)

# Plot for each transition using built-in visualization
for transition in summary:
    fig = MDTerp.plot_feature_importance(
        all_result_loc, feature_names_loc,
        transition=transition,
        show_std=False,
    )

# %%
# Cross-transition feature importance heatmap
fig = MDTerp.plot_importance_heatmap(all_result_loc, feature_names_loc)

# %%
# Unfaithfulness curve for first point of first transition
transitions = list(summary.keys())
fig = MDTerp.plot_unfaithfulness_curve(result_dir, transitions[0], 0)

# %%
# Per-point importance variability
fig = MDTerp.plot_point_variability(all_result_loc, feature_names_loc, transitions[0], top_n=4)

# %%
# For all the investigated points, fetch n_th dominant features (n = 0 is most dominant).
from MDTerp import dominant_feature
dominant_feature(all_result_loc, n=0)
# Out:
# {462032: np.int64(1),
#  686499: np.int64(1),
#  795149: np.int64(1),
#  1910967: np.int64(1),
#  1774573: np.int64(1),
#  519850: np.int64(1),
#  1252135: np.int64(1),
#  234333: np.int64(1),
#  152148: np.int64(1),
#  1977146: np.int64(1),
#  1826342: np.int64(1),
#  166468: np.int64(1),
#  1703236: np.int64(1),
#  1447480: np.int64(1),
#  1254684: np.int64(1),
#  1354231: np.int64(1),
#  1596397: np.int64(1),
#  929177: np.int64(1),
#  660150: np.int64(1),
#  1764389: np.int64(1),
#  954068: np.int64(1),
#  1827627: np.int64(1),
#  1564434: np.int64(1),
#  290531: np.int64(1),
#  158660: np.int64(1),
#  1329923: np.int64(1),
#  938900: np.int64(1),
#  1045904: np.int64(1),
#  361570: np.int64(1),
#  398620: np.int64(1),
#  491487: np.int64(1),
#  1483176: np.int64(1),
#  1059537: np.int64(1),
#  1343495: np.int64(1),
#  527219: np.int64(1),
#  429207: np.int64(1),
#  495762: np.int64(1),
#  130552: np.int64(1),
#  721498: np.int64(1),
#  1413324: np.int64(1),
#  43759: np.int64(1),
#  686498: np.int64(1),
#  983400: np.int64(1),
#  1711130: np.int64(1),
#  1344206: np.int64(1),
#  1036461: np.int64(1),
#  174912: np.int64(1),
#  653875: np.int64(1),
#  1641357: np.int64(1),
#  1145263: np.int64(1),
#  1954069: np.int64(1),
#  1655804: np.int64(1),
#  168645: np.int64(1),
#  1237230: np.int64(1),
#  822878: np.int64(1),
#  1982211: np.int64(1),
#  630009: np.int64(1),
#  703751: np.int64(1),
#  1268721: np.int64(1),
#  472278: np.int64(1),
#  132857: np.int64(1),
#  1754273: np.int64(1),
#  558926: np.int64(1),
#  1715598: np.int64(1),
#  711146: np.int64(1),
#  1771875: np.int64(1),
#  770764: np.int64(1),
#  86944: np.int64(1),
#  1221103: np.int64(1),
#  1774929: np.int64(1),
#  917143: np.int64(1),
#  250828: np.int64(1),
#  133121: np.int64(1),
#  1785567: np.int64(1),
#  817124: np.int64(1),
#  55155: np.int64(1),
#  1186514: np.int64(1),
#  1154111: np.int64(1),
#  1699395: np.int64(1),
#  939040: np.int64(1),
#  1535098: np.int64(1),
#  324007: np.int64(1),
#  1747603: np.int64(1),
#  661948: np.int64(1),
#  1055085: np.int64(1),
#  575902: np.int64(1),
#  532370: np.int64(1),
#  1639123: np.int64(1),
#  917789: np.int64(1),
#  1696404: np.int64(1),
#  271316: np.int64(1),
#  339021: np.int64(1),
#  1581758: np.int64(1),
#  311710: np.int64(1),
#  1909827: np.int64(1),
#  1534931: np.int64(1),
#  1810302: np.int64(1),
#  1144137: np.int64(1),
#  654207: np.int64(1),
#  1347436: np.int64(1),
#  680975: np.int64(0),
#  879430: np.int64(0),
#  1950289: np.int64(0),
#  216891: np.int64(0),
#  879433: np.int64(0),
#  204667: np.int64(0),
#  742684: np.int64(0),
#  855571: np.int64(0),
#  1100942: np.int64(0),
#  879432: np.int64(0),
#  1914419: np.int64(0),
#  92143: np.int64(0),
#  204668: np.int64(0),
#  975796: np.int64(0),
#  1899728: np.int64(0),
#  606001: np.int64(0),
#  1143111: np.int64(0),
#  371987: np.int64(0),
#  1603951: np.int64(0),
#  808657: np.int64(0),
#  879434: np.int64(0),
#  619259: np.int64(0),
#  1258873: np.int64(0),
#  680972: np.int64(0),
#  1431463: np.int64(0),
#  566690: np.int64(0),
#  1145989: np.int64(0),
#  1602189: np.int64(0),
#  114940: np.int64(0),
#  855572: np.int64(0),
#  975795: np.int64(0),
#  375620: np.int64(0),
#  1284644: np.int64(0),
#  566688: np.int64(0),
#  1898484: np.int64(0),
#  879435: np.int64(0),
#  1935506: np.int64(0),
#  216890: np.int64(0),
#  1934800: np.int64(0),
#  1898483: np.int64(0),
#  1602191: np.int64(0),
#  1142886: np.int64(0),
#  998695: np.int64(0),
#  1145988: np.int64(0)}
